# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Ahmad Zaini Tholabi
# - **Email:** ahmadzaini1908@gmail.com
# - **ID Dicoding:** zainitholabi

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa saja produk yang paling laris?
#
# - Seberapa banyak uang yang telah dihabiskan oleh pelanggan dalam beberapa bulan terakhir?
#
# - Bagaimana penjualan di platform e-commerce berkembang seiring berjalannya waktu?
#
# - Bagaimana layanan kami membuat pelanggan puas?
#
# - Apakah ada perbedaan antara demografi pelanggan dan preferensi pembelian?
#
# - Tempat mana klien terbanyak bergantung pada lokasi geografis mereka?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
# !pip install unidecode
import unidecode
import matplotlib.image as mpimg

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
dataFrameCustomers = pd.read_csv('/content/customers_dataset.csv')
dataFrameCustomers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
dataFrameGeo = pd.read_csv('/content/geolocation_dataset.csv')
dataFrameGeo.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
orderItems = pd.read_csv('/content/order_items_dataset.csv')
orderItems.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
orderPayments = pd.read_csv('/content/order_payments_dataset.csv')
orderPayments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
orderReviews = pd.read_csv('/content/order_reviews_dataset.csv')
orderReviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
dataFrameOrders = pd.read_csv('/content/orders_dataset.csv')
dataFrameOrders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
productCategory = pd.read_csv('/content/product_category_name_translation.csv')
productCategory.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
dataFrameProducts = pd.read_csv('/content/products_dataset.csv')
dataFrameProducts.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
dataFrameSellers = pd.read_csv('/content/sellers_dataset.csv')
dataFrameSellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ### Eval Data

# %%
print('\n',dataFrameCustomers.info())
print('\n',dataFrameGeo.info())
print('\n',orderItems.info())
print('\n',orderPayments.info())
print('\n',orderReviews.info())
print('\n',dataFrameOrders.info())
print('\n',productCategory.info())
print('\n',dataFrameProducts.info())
print('\n',dataFrameSellers.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
# ...

# %% [markdown]
# ### Cek Data Null

# %%
print('\nInfo Data Null Customers',dataFrameCustomers.isnull().sum())
print('\nInfo Data Null Geolocation',dataFrameGeo.isnull().sum())
print('\nInfo Data Null Order Items',orderItems.isnull().sum())
print('\nInfo Data Null Order Payments',orderPayments.isnull().sum())
print('\nInfo Data Null Order Reviews',orderReviews.isnull().sum())
print('\nInfo Data Null Order',dataFrameOrders.isnull().sum())
print('\nInfo Data Null Product Category',productCategory.isnull().sum())
print('\nInfo Data Null Products',dataFrameProducts.isnull().sum())
print('\nInfo Data Null Sellers',dataFrameSellers.isnull().sum())
# Out:
# Info Data Null Customers customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Info Data Null Geolocation geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Info Data Null Order Items order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Info Data Null Order Payments order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Info Data Null Order Reviews review_id                      0
# order_id                       0
# review_score                   0
# ...

# %% [markdown]
# ### Cek Data Duplikat

# %%
print('\nInfo Data Duplikat Customers',dataFrameCustomers.duplicated().sum())
print('\nInfo Data Duplikat Geolocation',dataFrameGeo.duplicated().sum())
print('\nInfo Data Duplikat Order Items',orderItems.duplicated().sum())
print('\nInfo Data Duplikat Order Payments',orderPayments.duplicated().sum())
print('\nInfo Data Duplikat Order Reviews',orderReviews.duplicated().sum())
print('\nInfo Data Duplikat Order',dataFrameOrders.duplicated().sum())
print('\nInfo Data Duplikat Product Category',productCategory.duplicated().sum())
print('\nInfo Data Duplikat Products',dataFrameProducts.duplicated().sum())
print('\nInfo Data Duplikat Sellers',dataFrameSellers.duplicated().sum())
# Out:
# Info Data Duplikat Customers 0
#
# Info Data Duplikat Geolocation 261831
#
# Info Data Duplikat Order Items 0
#
# Info Data Duplikat Order Payments 0
#
# Info Data Duplikat Order Reviews 0
#
# Info Data Duplikat Order 0
#
# Info Data Duplikat Product Category 0
#
# Info Data Duplikat Products 0
#
# Info Data Duplikat Sellers 0

# %%
print('\nInfo Data Describe Customers',dataFrameCustomers.describe(include='all'))
print('\nInfo Data Describe Geolocation',dataFrameGeo.describe(include='all'))
print('\nInfo Data Describe Order Items',orderItems.describe(include='all'))
print('\nInfo Data Describe Order Payments',orderPayments.describe(include='all'))
print('\nInfo Data Describe Order Reviews',orderReviews.describe(include='all'))
print('\nInfo Data Describe Order',dataFrameOrders.describe(include='all'))
print('\nInfo Data Describe Product Category',productCategory.describe(include='all'))
print('\nInfo Data Describe Products',dataFrameProducts.describe(include='all'))
print('\nInfo Data Describe Sellers',dataFrameSellers.describe(include='all'))
# Out:
# Info Data Describe Customers                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
# ...

# %%
dataFrameGeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ### Tidak ada drop duplikat karena data duplikat ada pada dataset geolocation. Mungkin nilai tertinggi untuk kolom "geolocation_city" dan "geolocation_state" adalah Sao Paulo (SP).

# %%
orderReviews[orderReviews.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
orderReviews.review_comment_title.value_counts()
# Out:
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: review_comment_title, Length: 4527, dtype: int64

# %%
orderReviews[orderReviews.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %%
orderReviews.review_comment_message.value_counts()
# Out:
# Muito bom                                                                                                                                                                                              230
# Bom                                                                                                                                                                                                    189
# muito bom                                                                                                                                                                                              122
# bom                                                                                                                                                                                                    107
# ...

# %%
orderReviews.fillna(value="no comment", inplace=True)

# %%
dataFrameOrders[dataFrameOrders.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
datetime_oi = ["shipping_limit_date"]

for column in datetime_oi:
  orderItems[column] = pd.to_datetime(orderItems[column])

# %%
datetime_or = ["review_creation_date","review_answer_timestamp"]

for column in datetime_or:
  orderReviews[column] = pd.to_datetime(orderReviews[column])

# %%
datetime_oo = ["order_purchase_timestamp","order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"]

for column in datetime_oo:
  dataFrameOrders[column] = pd.to_datetime(dataFrameOrders[column])

# %%
orderItems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
orderReviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
dataFrameOrders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore dataFrameCustomers

# %%
dataFrameCustomers.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 11381  e13a5ed086aacc9b2b7466c78645b468  6e4df650faf2c070fc5cbc95efd6c01a
# 94634  9fa1306390b435305462a28f708c783b  0be330030885cb5b0cd0fc84f90d4ad5
# 32029  062d526eabc36e995e3a9ce353894fcb  039024d7c7249fe937d2e306af33e446
# 76894  cf361a577c7a3a851422f48baf8fc07f  4b8d6f6291cad9a96bfdbe5376a995e1
# 49251  a934cd48fb6e90dd20b8179679223cea  7ac64387853d0d536a94cbdc78b5effb
#
#        customer_zip_code_prefix customer_city customer_state
# 11381                      9360          maua             SP
# 94634                     85015    guarapuava             PR
# 32029                     67013    ananindeua             PA
# 76894                     13575    sao carlos             SP
# 49251                     16370     promissao             SP

# %%
dataFrameCustomers.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
dataFrameCustomers.customer_id.is_unique
# Out:
# True

# %%
dataFrameCustomers.customer_id.duplicated
# Out:
# <bound method Series.duplicated of 0        06b8999e2fba1a1fbc88172c00ba8bc7
# 1        18955e83d337fd6b2def6b18a428ac77
# 2        4e7b3e00288586ebd08712fdd0374a03
# 3        b2b6027bc5c5109e529d4dc6358b12c3
# 4        4f2d8ab171c80ec8364f7c12e35b23ad
#                        ...
# 99436    17ddf5dd5d51696bb3d7c6291687be6f
# 99437    e7b71a9017aa05c9a7fd292d714858e8
# 99438    5e28dfe12db7fb50a4b2f691faecea5e
# 99439    56b18e2166679b8a959d72dd06da27f9
# 99440    274fa6071e5e17fe303b9748641082c8
# Name: customer_id, Length: 99441, dtype: object>

# %%
dataFrameCustomers.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
dataFrameCustomers.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
orderPayments.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 83127  7c67e69218256034fdfb7f4507c85906                   1  credit_card
# 69903  79ba9ff956399f8ca9eaa802139851fd                   1       boleto
# 34050  25b66d9cb3dd45d25788fdb3e226c5b9                   1  credit_card
# 69651  3f9666fbcb3490ff8c1f0d2b826c32db                   1  credit_card
# 24256  27a940efdd448db29463b53ea0cfa2f4                   8      voucher
#
#        payment_installments  payment_value
# 83127                     1          98.16
# 69903                     1         115.44
# 34050                     2         129.11
# 69651                     1         299.96
# 24256                     1           7.80

# %%
orderPayments.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
orderPayments.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
dataFrameOrders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 86242  76d02bba227a9b675d413ce36b7231c6  753c62e8a94b6f213074e9a8999e6922
# 47128  9dc19c953a97c92383ff95f54cabe58a  ded50eb532c0c1903c0835e0d7749b97
# 6383   97c62fe0812570f61cb83cce52b4884e  607dd59480435054b322d1dfe2728446
# 98306  163ad1666638554c03eff2545773c4b3  f315e987b6e111d0b9f8e1dc6c5b3948
# 79541  7c456a887b23a75268a45a224d191c52  b31f9f275c6f4ab74a60d0bebb303f0b
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 86242    delivered      2017-09-16 16:24:07 2017-09-16 16:35:16
# 47128    delivered      2017-04-16 09:19:55 2017-04-16 09:30:15
# 6383     delivered      2018-01-23 22:05:33 2018-01-23 22:17:26
# 98306    delivered      2017-10-01 19:48:02 2017-10-03 03:49:16
# 79541    delivered      2018-04-18 11:42:32 2018-04-18 11:55:21
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 86242          2017-09-19 19:58:11           2017-09-27 16:14:30
# ...

# %%
deliveryTime = dataFrameOrders["order_delivered_customer_date"] - dataFrameOrders["order_delivered_carrier_date"]
deliveryTime = deliveryTime.apply(lambda x: x.total_seconds())
dataFrameOrders["deliveryTime"] = round(deliveryTime/86400)

# %%
dataFrameOrders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 46417  594013e81f2c775b3fb2591f7e4bd4a9  653f5d3367160dc1985d939aa321a3bd
# 42467  4ed7bfce6beab8e845d01d46439d9ad9  f1f4fae012d2a40ec2bb1a76610cb42e
# 5687   57e27e0f4ce02fc858627e4c46e51e9d  0277bd798b42071cb092b1795dbae947
# 64341  32d7800197408f1dc16884bf75997754  eb4050f3fed9cbc10a3190ac4bd66ff9
# 37291  58faef88b9fbcce2db4d1b68bdb0c2a3  4062747ee07fe2bcd812937bbfc4304f
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 46417    delivered      2018-02-28 11:16:21 2018-03-01 12:10:14
# 42467    delivered      2018-01-17 01:57:30 2018-01-17 02:10:24
# 5687     delivered      2018-04-03 19:04:17 2018-04-03 19:15:24
# 64341    delivered      2017-11-22 22:49:54 2017-11-22 23:06:22
# 37291    delivered      2017-03-23 21:08:47 2017-03-23 21:22:42
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 46417          2018-03-02 16:56:59           2018-03-05 15:22:00
# ...

# %%
print(dataFrameOrders.columns)
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'deliveryTime'],
#       dtype='object')

# %%
dataFrameOrders.deliveryTime.hist()
# Out:
# <Axes: >

# %%
customer_id_in_dataFrameOrders = dataFrameOrders.customer_id.values

dataFrameCustomers["status"] = dataFrameCustomers["customer_id"].apply(lambda x: "Active" if x in customer_id_in_dataFrameOrders else "Non Active")

dataFrameCustomers.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 41017  c57b4ec1791188f1d3b38bc85b208a3c  08356b77e4dd0fa07cfadac1a45eaec7
# 2493   3c9e199c72090dad38052fb09243f620  08dc0f9b1d3b44c23a697013a9b1b61f
# 71317  512ded1d728a366069702fd124de9a6c  52ab2b4a66e349e6711f86bc7c7026bd
# 38190  25370debebc4aa0de58614a2478bf59c  119f667b7cf79615e41d41bb601b02b2
# 18699  c6cbf7166d1b72d60b6217b90990d9bc  4190cd95848f843958c430791350f965
#
#        customer_zip_code_prefix customer_city customer_state  status
# 41017                      1033     sao paulo             SP  Active
# 2493                      13590       dourado             SP  Active
# 71317                     14580         guara             SP  Active
# 38190                     80030      curitiba             PR  Active
# 18699                     14620      orlandia             SP  Active

# %%
dataFrameCustomers.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Merge dataFrameCustomers & dataFrameOrders

# %% [markdown]
# ### Visualisasi & Penjelasan Analysis

# %%
dataFrameCustomersOders = pd.merge(
    left=dataFrameCustomers,
    right=dataFrameOrders,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
dataFrameCustomersOders.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
dataFrameCustomersOders.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %%
dataFrameCustomersOders.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: order_id, dtype: int64

# %%
dataFrameCustomersOders.groupby(by="customer_zip_code_prefix").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_zip_code_prefix
# 22790    142
# 24220    124
# 22793    121
# 24230    117
# 22775    110
# 29101    101
# 13212     95
# 35162     93
# 22631     89
# 38400     87
# Name: order_id, dtype: int64

# %%
dataFrameCustomersOders.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %% [markdown]
# **Merge orderPayments & orderReviews**

# %%
dataFrameOrderPayRev = pd.merge(
    left=orderPayments,
    right=orderReviews,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
dataFrameOrderPayRev.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
dataFrameOrderPayRev.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
dataFrameOrderPayRev.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 20031  8bcbe01d44d147f901cd3192671144db                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
dataFrameOrderPayRev.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# ### Merge dataFrameCustomersOders & dataFrameOrderPayRev

# %%
dataFrameCustomers = pd.merge(
    left=dataFrameCustomersOders,
    right=dataFrameOrderPayRev,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
dataFrameCustomers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore orderItems & dataFrameSellers

# %% [markdown]
# #### Merge orderItems & dataFrameSellers

# %%
dataFrameItemSeller = pd.merge(
    left=orderItems,
    right=dataFrameSellers,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
dataFrameItemSeller.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
dataFrameItemSeller.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Explore dataFrameProducts & productCategory
# #### Merge dataFrameProducts & productCategory

# %%
dataFrameProducts = pd.merge(
    left=dataFrameProducts,
    right=productCategory,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
dataFrameProducts.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
dataFrameProducts.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
print(dataFrameProducts.columns)
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english'],
#       dtype='object')

# %%
dataFrameProducts.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# ### Merge dataFrameItemSeller & dataFrameProducts

# %%
dataFrameSellers = pd.merge(
    left=dataFrameProducts,
    right=dataFrameItemSeller,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
dataFrameSellers.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
dataFrameSellers.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20528  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 73922  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 49503  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 71835  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 32232  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55911  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55903  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29610  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29608  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29609  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
# ...

# %%
dataFrameSellers.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Explore dataFrameGeo

# %%
dataFrameGeo.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 953488                        92420       -29.885084       -51.184484
# 516306                        28460       -21.411897       -42.206156
# 179991                         7091       -23.465090       -46.541468
# 781117                        70342       -15.806872       -47.891566
# 17878                          1533       -23.571085       -46.639034
#
#        geolocation_city geolocation_state
# 953488           canoas                RS
# 516306         miracema                RJ
# 179991        guarulhos                SP
# 781117         brasilia                DF
# 17878         sao paulo                SP

# %%
def pretty_string(column):
    column_space = ' '.join(column.split())
    return unidecode.unidecode(column_space.lower())

# %%
dataFrameGeo['geolocation_city'] = dataFrameGeo['geolocation_city'].apply(pretty_string)

# %%
dataFrameGeo.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
dataFrameGeo[dataFrameGeo['geolocation_zip_code_prefix'] == 24220].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470805                        24220       -22.905817       -43.106989
# 470811                        24220       -22.902306       -43.112545
# 470812                        24220       -22.904567       -43.110491
# 470820                        24220       -22.902575       -43.109192
# 470821                        24220       -22.907500       -43.106170
#
#        geolocation_city geolocation_state
# 470805          niteroi                RJ
# 470811          niteroi                RJ
# 470812          niteroi                RJ
# 470820          niteroi                RJ
# 470821          niteroi                RJ

# %% [markdown]
# ### Explore Semua Data
# ### Merge Semua Data
# Saya pikir dataset geolocation tidak diperlukan dalam hal ini, jadi saya tidak menggabungkannya.

# %%
semuaData = pd.merge(
    left=dataFrameCustomers,
    right=dataFrameSellers,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
semuaData.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
semuaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119143 entries, 0 to 119142
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    119143 non-null  object
#  1   customer_unique_id             119143 non-null  object
#  2   customer_zip_code_prefix       119143 non-null  int64
#  3   customer_city                  119143 non-null  object
#  4   customer_state                 119143 non-null  object
#  5   status                         119143 non-null  object
#  6   order_id                       119143 non-null  object
#  7   order_status                   119143 non-null  object
#  8   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  9   order_approved_at              118966 non-null  datetime64[ns]
#  10  order_delivered_carrier_date   117057 non-null  datetime64[ns]
# ...

# %%
semuaData.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                     price  freight_value
# customer_city       product_category_name_english
# abadia dos dourados books_general_interest          39.90          18.38
#                     cool_stuff                     199.00          20.63
#                     sports_leisure                 120.00          15.59
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
# ...                                                   ...            ...
# ze doca             food_drink                      65.00          38.00
#                     garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#                     sports_leisure                 149.90          38.60
# zortea              computers_accessories           69.90          20.98
#
# [25199 rows x 2 columns]

# %%
semuaData.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                 price  freight_value
# customer_state product_category_name_english
# AC             auto                            606.97         146.42
#                baby                            697.84         174.13
#                bed_bath_table                  567.70         157.51
#                books_general_interest          633.80         123.71
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 5533.32        1393.53
#                stationery                      276.80          73.80
#                telephony                      1268.12         627.34
#                toys                           1864.15         423.96
#                watches_gifts                  5446.89         950.02
#
# [1356 rows x 2 columns]

# %%
semuaData.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41746     7726078.35
# RJ                 12852     2795615.67
# MG                 11635     2351221.09
# RS                  5466     1160175.66
# PR                  5045     1079795.49
# BA                  3380      805070.98
# SC                  3637      801276.45
# GO                  2020      520481.65
# DF                  2140      438095.32
# ES                  2033      408611.64
# PE                  1652      380294.18
# CE                  1336      349290.36
# PA                   975      263217.70
# MT                   907      257802.26
# MA                   747      200363.24
# PB                   536      181660.73
# MS                   715      167670.27
# PI                   495      137158.89
# RN                   485      117192.91
# AL                   413      112296.47
# SE                   350       90651.44
# TO                   280       72412.08
# ...

# %%
semuaData.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         182          1.0  5.0
# air_conditioning                   253          1.0  5.0
# art                                202          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              350          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2311          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4199          1.0  5.0
# toys                              3886          1.0  5.0
# watches_gifts                     5624          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Convert semuaData to .csv

# %%
semuaData.to_csv('semuaData.csv', index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk apa yang terjual paling banyak dan paling sedikit?

# %%
dataFrameSumOrdItems = semuaData.groupby("product_category_name_english")["product_id"].count().reset_index()
dataFrameSumOrdItems = dataFrameSumOrdItems.rename(columns={"product_id": "products"})
dataFrameSumOrdItems = dataFrameSumOrdItems.sort_values(by="products", ascending=False)
dataFrameSumOrdItems = dataFrameSumOrdItems.head(10)

dataFrameSumOrdItems.head()
# Out:
#    product_category_name_english  products
# 7                 bed_bath_table     11988
# 43                 health_beauty     10032
# 65                sports_leisure      9004
# 39               furniture_decor      8832
# 15         computers_accessories      8150

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#068DA9", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="products", y="product_category_name_english", data=dataFrameSumOrdItems.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk terjual paling banyak", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="products", y="product_category_name_english", data=dataFrameSumOrdItems.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk terjual paling sedikit", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Produk terjual paling banyak dan paling sedikit", fontsize=20)
plt.show()
# Out:
# <ipython-input-174-e606f097b609>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=dataFrameSumOrdItems.head(5), palette=colors, ax=ax[0])
# <ipython-input-174-e606f097b609>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=dataFrameSumOrdItems.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# Terlihat pada grafik diatas, Produk yang terjual paling banyak adalah bed_bath_table. dan produk yang terjual paling sedikit adalah auto.

# %% [markdown]
# ### Pertanyaan 2: Seiring berjalannya waktu, bagaimana kinerja penjualan platform E-Commerce kami?

# %%
dataFrameMonthly = semuaData.resample(rule='M', on='order_approved_at').agg({
    "order_id": "nunique",
})
dataFrameMonthly.index = dataFrameMonthly.index.strftime('%B') #mengubah format order_approved_at menjadi Tahun-Bulan
dataFrameMonthly = dataFrameMonthly.reset_index()
dataFrameMonthly.rename(columns={
    "order_id": "order_count",
}, inplace=True)
dataFrameMonthly.head()
# Out:
#   order_approved_at  order_count
# 0         September            1
# 1           October          320
# 2          November            0
# 3          December            1
# 4           January          760

# %%
dataFrameMonthly = dataFrameMonthly.sort_values('order_count').drop_duplicates('order_approved_at', keep='last')

# %%
dataFrameMonthly.head()
# Out:
#    order_approved_at  order_count
# 12         September         4301
# 13           October         4590
# 15          December         5832
# 21              June         6164
# 22              July         6176

# %%
dataFrameMonthly.sort_values(by='order_count')
# Out:
#    order_approved_at  order_count
# 12         September         4301
# 13           October         4590
# 15          December         5832
# 21              June         6164
# 22              July         6176
# 23            August         6620
# 17          February         6706
# 19             April         6778
# 20               May         7066
# 16           January         7187
# 18             March         7288
# 14          November         7395

# %%
monthMapping = {
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August": 8,
    "September": 9,
    "October": 10,
    "November": 11,
    "December": 12
}

dataFrameMonthly["month_numeric"] = dataFrameMonthly["order_approved_at"].map(monthMapping)
dataFrameMonthly = dataFrameMonthly.sort_values("month_numeric")
dataFrameMonthly = dataFrameMonthly.drop("month_numeric", axis=1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    dataFrameMonthly["order_approved_at"],
    dataFrameMonthly["order_count"],
    marker='o',
    linewidth=2,
    color="#068DA9"
)
plt.title("Angka Orders per Bulan (2018)", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Bulan September menunjukkan penurunan yang signifikan, dan bulan November menunjukkan kenaikan yang signifikan.

# %% [markdown]
# ### Pertanyaan 3: Berapa banyak uang yang telah dihabiskan pelanggan dalam beberapa bulan terakhir?

# %%
dataFrameMonthlySpend = semuaData.resample(rule='M', on='order_approved_at').agg({
    "payment_value":"sum"
})
dataFrameMonthlySpend.index = dataFrameMonthlySpend.index.strftime('%B') #mengubah format order_approved_at menjadi Tahun-Bulan
dataFrameMonthlySpend = dataFrameMonthlySpend.reset_index()
dataFrameMonthlySpend.rename(columns={
    "payment_value":"total_spend"
}, inplace=True)
dataFrameMonthlySpend.head()
# Out:
#   order_approved_at  total_spend
# 0         September         0.00
# 1           October     75985.54
# 2          November         0.00
# 3          December        19.62
# 4           January    182178.36

# %%
dataFrameMonthlySpend = dataFrameMonthlySpend.sort_values('total_spend').drop_duplicates('order_approved_at', keep='last')

# %%
dataFrameMonthlySpend.head()
# Out:
#   order_approved_at  total_spend
# 0         September         0.00
# 1           October     75985.54
# 2          November         0.00
# 3          December        19.62
# 4           January    182178.36

# %%
dataFrameMonthlySpend.sort_values(by='total_spend')
# Out:
#    order_approved_at  total_spend
# 0          September         0.00
# 2           November         0.00
# 3           December        19.62
# 24         September       166.46
# 1            October     75985.54
# 4            January    182178.36
# 5           February    350023.57
# 7              April    506593.88
# 6              March    547228.40
# 9               June    620191.15
# 8                May    736346.88
# 10              July    739098.77
# 11            August    882476.79
# 12         September    927821.13
# 15          December   1092932.59
# 13           October   1138730.07
# 23            August   1268960.54
# 21              June   1306785.03
# 17          February   1314882.87
# 22              July   1334156.42
# 16           January   1406557.66
# 19             April   1476502.25
# 18             March   1500474.01
# 20               May   1545868.81
# 14          November   1588308.55

# %%
dataFrameMonthlySpend["month_numeric"] = dataFrameMonthlySpend["order_approved_at"].map(monthMapping)
dataFrameMonthlySpend = dataFrameMonthlySpend.sort_values("month_numeric")
dataFrameMonthlySpend = dataFrameMonthlySpend.drop("month_numeric", axis=1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    dataFrameMonthlySpend["order_approved_at"],
    dataFrameMonthlySpend["total_spend"],
    marker='o',
    linewidth=2,
    color="#068DA9"
)
plt.title("Total uang yang dibelanjakan pelanggan per Bulan (2018)", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Pada grafik di atas, jumlah uang yang paling banyak dihabiskan pada bulan November dan jumlah uang paling sedikit dihabiskan pada bulan September.

# %% [markdown]
# ### Pertanyaan 4 : Bagaimana kepuasan pelanggan dengan layanan kami?

# %%
reviewScores = semuaData['review_score'].value_counts().sort_values(ascending=False)

most_common_score = reviewScores.idxmax()

sns.set(style="darkgrid")

plt.figure(figsize=(10, 5))
sns.barplot(x=reviewScores.index,
            y=reviewScores.values,
            order=reviewScores.index,
            palette=["#068DA9" if score == most_common_score else "#D3D3D3" for score in reviewScores.index]
            )

plt.title("Penilaian oleh pelanggan atas layanan kami", fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Count")
plt.xticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-194-3371ccef557e>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=reviewScores.index,

# %% [markdown]
# Grafik di atas menunjukkan bahwa pelanggan sangat puas dengan layanan yang diberikan; data menunjukkan bahwa pelanggan dengan rating 5 memiliki jumlah data yang paling banyak.

# %% [markdown]
# ### Pertanyaan 5 : Apakah ada perbedaan antara demografi pelanggan kami dan preferensi pembelian mereka?

# %% [markdown]
# ### Berdasarkan customer_state

# %%
dataFrameBystate = semuaData.groupby(by="customer_state").customer_id.nunique().reset_index()
dataFrameBystate.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
dataFrameBystate.head()
# Out:
#   customer_state  customer_count
# 0             AC              81
# 1             AL             413
# 2             AM             148
# 3             AP              68
# 4             BA            3380

# %%
plt.figure(figsize=(12, 6))

most_common_state = dataFrameBystate.loc[dataFrameBystate['customer_count'].idxmax(), 'customer_state']

dataFrameBystate = dataFrameBystate.sort_values(by='customer_count', ascending=False)

sns.barplot(x='customer_state',
            y='customer_count',
            data=dataFrameBystate,
            palette=["#068DA9" if state == most_common_state else "#D3D3D3" for state in dataFrameBystate['customer_state']]
            )

plt.title("Jumlah pelanggan dari Negara Bagian", fontsize=15)
plt.xlabel("Negara Bagian")
plt.ylabel("Jumlah Pelanggan")
plt.xticks(fontsize=10)
plt.show()
# Out:
# <ipython-input-196-9bbb95e674e6>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='customer_state',

# %% [markdown]
# Pada grafik di atas, berdasarkan negara bagian, SP memiliki data pelanggan yang paling banyak.

# %%
dataFrameBycity = semuaData['customer_city'].value_counts().head(10)

plt.figure(figsize=(12, 6))

most_common_city = dataFrameBycity.idxmax()

dataFrameBycity = dataFrameBycity.sort_values(ascending=False)

sns.barplot(x=dataFrameBycity.index,
            y=dataFrameBycity.values,
            palette=["#068DA9" if city == most_common_city else "#D3D3D3" for city in dataFrameBycity.index]
            )

plt.title("Jumlah Pelanggan dari Setiap Kota", fontsize=15)
plt.xlabel("Kota")
plt.ylabel("Jumlah Pelanggan")
plt.xticks(rotation=45, fontsize=10)
plt.show()
# Out:
# <ipython-input-198-1924841cdc27>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dataFrameBycity.index,

# %% [markdown]
# Pada grafik diatas berdasarkan City, sao paulo memiliki data customer terbanyak.

# %%
jmlStatusOrder = semuaData['order_status'].value_counts()

plt.figure(figsize=(8, 6))
jmlStatusOrder.plot(kind='bar', color='skyblue')
plt.title('Status Order')
plt.xlabel('Status')
plt.ylabel('Jumlah Orders')
plt.show()

# %% [markdown]
# Pada grafik di atas, status order tertinggi adalah delivered.

# %% [markdown]
# ### Pertanyaan 6 : Di mana lokasi geografis memiliki jumlah pelanggan tertinggi?

# %%
geoOtherState = dataFrameGeo.groupby(['geolocation_zip_code_prefix'])['geolocation_state'].nunique().reset_index(name='count')
geoOtherState[geoOtherState['count']>= 2].shape
max_state = dataFrameGeo.groupby(['geolocation_zip_code_prefix','geolocation_state']).size().reset_index(name='count').drop_duplicates(subset = 'geolocation_zip_code_prefix').drop('count',axis=1)

# %%
geoSilver = dataFrameGeo.groupby(['geolocation_zip_code_prefix','geolocation_city','geolocation_state'])[['geolocation_lat','geolocation_lng']].median().reset_index()
geoSilver = geoSilver.merge(max_state,on=['geolocation_zip_code_prefix','geolocation_state'],how='inner')

# %%
custSilver = dataFrameCustomers.merge(geoSilver,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='inner')

# %%
custSilver.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  5dca924cc99eea2dc5ba40d11ec5dd0f  2761fee7f378f0a8d7682d8a3fa07ab1
# 2  661897d4968f1b59bfff74c7eb2eb4fc  d06a495406b79cb8203ea21cc0942f8c
# 3  702b62324327ccba20f1be3465426437  8b3d988f330c1d1c3332ccd440c147b7
# 4  bdf997bae7ca819b0415f5174d6b4302  866755e25db620f8d7e81b351a15bb2f
#
#    customer_zip_code_prefix customer_city customer_state  status  \
# 0                     14409        franca             SP  Active
# 1                     14409        franca             SP  Active
# 2                     14409        franca             SP  Active
# 3                     14409        franca             SP  Active
# 4                     14409        franca             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# ...

# %%
custSilver.to_csv("geoLoc.csv", index=False)

# %%
def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen('https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'),'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3,s=0.3,c='maroon')
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
    plt.show()

# %%
plot_brazil_map(custSilver.drop_duplicates(subset='customer_unique_id'))

# %% [markdown]
# Banyak pelanggan kami berasal dari negara bagian selatan dan tenggara.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Produk apa yang terjual paling banyak dan paling sedikit?
# > Hasil visualisasi menunjukkan bahwa pelanggan lebih sering membeli produk bed-bath-table dan produk auto, yang paling tidak banyak dibeli.
# - Seiring berjalannya waktu, bagaimana kinerja penjualan platform E-Commerce kami?
# > Performa penjualan E-Commerce stabil dari Januari hingga Mei, menurun sedikit pada bulan Juni hingga Juli, meningkatkan sedikit pada bulan Agustus, dan mengalami penurunan yang signifikan pada bulan September sebelumnya. Pada bulan Oktober hingga November, terjadi kenaikan yang signifikan, tetapi kembali menurun pada bulan Desember.
# - Berapa banyak uang yang telah dihabiskan pelanggan dalam beberapa bulan terakhir?
# > Berdasarkan hasil visualisasi yang sudah ditampilkan, sesuai dengan grafik pada pertanyaan ke 2 total uang yang dihabiskan customer pada bulan Januari - Mei stabil terjadi penurunan pada bulan Juni-September, kenaikan signifikan pada bulan Oktober-November, dan kembali menurun pada bulan Desember.
# - Bagaimana kepuasan pelanggan dengan layanan kami?
# > Kepuasan pelanggan terhadap layanan yang diberikan sangatlah memuaskan, seperti yang ditunjukkan oleh visualisasi yang sudah ditampilkan, di mana banyak pelanggan memberikan rating 5 dan rating 4 di urutan kedua.
# - Apakah ada perbedaan antara demografi pelanggan kami dan preferensi pembelian mereka?
# > Negara bagian dengan pelanggan terbanyak adalah SP, dengan kota terbanyak adalah Sao Paulo. Negara bagian kedua dengan pelanggan terbanyak adalah RJ (Rio de Janeiro). Selain itu, item yang dipesan oleh pelanggan paling sering dikirim, yang berarti bahwa item yang dipesan oleh pelanggan tidak terjadi kesalahan dan telah dikirim dengan sukses ke pelanggan. Customer ini juga menerima rating 5 untuk pelayanan e-commerce.
# - Tempat manakah mayoritas pelanggan berada?
# > Grafik sebelumnya menunjukkan bahwa bagian selatan dan tenggara memiliki lebih banyak pelanggan. Kota-kota ibu kota, seperti São Paulo, Rio de Janeiro, Porto Alegre, dan lainnya, juga memiliki lebih banyak pelanggan.
